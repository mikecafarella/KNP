# %%
from client.knps.ORM_client import createRelation, WikiDataProperty
import client.knps.func_lib as func_lib
import pandas as pd
import math

# %%
r = createRelation("Q177220")
r.extend("P106", True, "Singer", label=True, limit=5000)
r.changeFocus("Singer_P106")
r.extend("P569", False, "Date_of_Birth")
r.extend("P570", False, "Date_of_Death")
r.extend("P136", False, "Genre", label=True)
r.query()
r.df
# Out:
#                                    Entity ID  \
# 0     http://www.wikidata.org/entity/Q177220
# 1     http://www.wikidata.org/entity/Q177220
# 2     http://www.wikidata.org/entity/Q177220
# 3     http://www.wikidata.org/entity/Q177220
# 4     http://www.wikidata.org/entity/Q177220
# ...                                      ...
# 4995  http://www.wikidata.org/entity/Q177220
# 4996  http://www.wikidata.org/entity/Q177220
# 4997  http://www.wikidata.org/entity/Q177220
# 4998  http://www.wikidata.org/entity/Q177220
# 4999  http://www.wikidata.org/entity/Q177220
#
#                                  Singer_P106   Singer_P106Label  \
# 0      http://www.wikidata.org/entity/Q43874       Eddie Murphy
# 1      http://www.wikidata.org/entity/Q43950       Jacob Artist
# 2      http://www.wikidata.org/entity/Q44780       Howlin' Wolf
# 3      http://www.wikidata.org/entity/Q43901         Jakob Geis
# 4      http://www.wikidata.org/entity/Q43432  Justin Timberlake
# ...                                      ...                ...
# 4995  http://www.wikidata.org/entity/Q272092        Ruby Keeler
# 4996  http://www.wikidata.org/entity/Q272069       Damon Albarn
# 4997  http://www.wikidata.org/entity/Q271679          Selah Sue
# 4998  http://www.wikidata.org/entity/Q271782      Betty Buckley
# 4999  http://www.wikidata.org/entity/Q272012    Eddie Van Halen
#
#         Date_of_Birth_P569    Date_of_Death_P570  \
# 0     1961-04-03T00:00:00Z                    NA
# 1     1992-10-17T00:00:00Z                    NA
# 2     1910-06-10T00:00:00Z  1976-01-08T00:00:00Z
# 3     1840-12-27T00:00:00Z  1908-03-03T00:00:00Z
# 4     1981-01-31T00:00:00Z                    NA
# ...                    ...                   ...
# 4995  1910-08-25T00:00:00Z  1993-02-28T00:00:00Z
# 4996  1968-03-23T00:00:00Z                    NA
# 4997  1989-05-03T00:00:00Z                    NA
# 4998  1947-07-03T00:00:00Z                    NA
# 4999  1955-01-26T00:00:00Z  2020-10-06T00:00:00Z
#
#                                    Genre_P136          Genre_P136Label  \
# 0      http://www.wikidata.org/entity/Q157443              comedy film
# 1                                          NA                       NA
# 2        http://www.wikidata.org/entity/Q8341                     jazz
# 3                                          NA                       NA
# 4       http://www.wikidata.org/entity/Q45981         rhythm and blues
# ...                                       ...                      ...
# 4995                                       NA                       NA
# 4996   http://www.wikidata.org/entity/Q189045                  Britpop
# 4997    http://www.wikidata.org/entity/Q45981         rhythm and blues
# 4998                                       NA                       NA
# 4999  http://www.wikidata.org/entity/Q1133657  traditional heavy metal
#
#      Basic ID
# 0     Q177220
# 1     Q177220
# 2     Q177220
# 3     Q177220
# 4     Q177220
# ...       ...
# 4995  Q177220
# 4996  Q177220
# 4997  Q177220
# 4998  Q177220
# 4999  Q177220
#
# [5000 rows x 8 columns]

# %%
import datetime
def age_calc(birth, death):
    try:
        if birth == 'NA':
            return None
        birth_date = datetime.datetime.strptime(birth[:4], '%Y')
        if death == 'NA':
            end_date = datetime.datetime.now()
        else:
            end_date = datetime.datetime.strptime(death[:4], '%Y')

        return end_date.year - birth_date.year - ((end_date.month, end_date.day) < (birth_date.month, birth_date.day))
    except:
        return None

def is_deceased(death_date):
    return death_date != 'NA'
        
r.extendWithFunction(['Date_of_Birth_P569','Date_of_Death_P570'], age_calc, 'Age')
r.extendWithFunction(['Date_of_Death_P570'], is_deceased, 'Deceased')

r.df[['Singer_P106Label', 'Genre_P136Label', 'Age', 'Deceased']]
# Out:
#        Singer_P106Label          Genre_P136Label   Age  Deceased
# 0          Eddie Murphy              comedy film  60.0     False
# 1          Jacob Artist                       NA  29.0     False
# 2          Howlin' Wolf                     jazz  66.0      True
# 3            Jakob Geis                       NA  68.0      True
# 4     Justin Timberlake         rhythm and blues  40.0     False
# ...                 ...                      ...   ...       ...
# 4995        Ruby Keeler                       NA  83.0      True
# 4996       Damon Albarn                  Britpop  53.0     False
# 4997          Selah Sue         rhythm and blues  32.0     False
# 4998      Betty Buckley                       NA  74.0     False
# 4999    Eddie Van Halen  traditional heavy metal  65.0      True
#
# [5000 rows x 4 columns]

# %%
r.df['Age'] = r.df['Age'].astype(float)
valid_age = r.df[r.df['Age'] > 0]
avg_death_age = valid_age[valid_age['Deceased']].groupby('Genre_P136Label').Age.agg(['count','mean'])

data = avg_death_age[avg_death_age['count'] >= 10].sort_values(by=['mean'])

print("Youngest Average Age at Death")
print(data[:10])
print("\n","-"*50)
print("Oldest Average Age at Death")
print(data[-10:])
# Out:
# Youngest Average Age at Death
#                   count       mean
# Genre_P136Label
# psychedelic rock     11  54.000000
# rock music           47  56.063830
# pop music            74  61.256757
# funk                 11  61.454545
# soul music           33  61.727273
# country music        43  64.720930
# pop                  18  66.166667
# folk music           16  66.187500
# blues                60  66.350000
# rhythm and blues     25  66.360000
#
#  --------------------------------------------------
# Oldest Average Age at Death
#                          count       mean
# Genre_P136Label
# pop                         18  66.166667
# folk music                  16  66.187500
# blues                       60  66.350000
# rhythm and blues            25  66.360000
# chanson                     24  69.041667
# jazz                        67  71.104478
# NA                         404  71.418317
# opera                      102  71.901961
# Western classical music     32  73.406250
# traditional pop music       14  74.285714

# %%
r2 = createRelation("Q2389789", subclass=True)
r2.extend("P31", True, "Coaster", label=True)
r2.changeFocus("Coaster_P31")
r2.extend("P2048", False, "Height")
r2.extend("P131", False, "Location", label=True)
r2.extend("P17", False, "Country", label=True)
r2.extend("P361", False, "Park", label=True)
r2.query()
r2.df[r2.df['Height_P2048'] != 'NA'][['Coaster_P31Label', 'Height_P2048', 'Park_P361Label', 'Location_P131Label', 'Country_P17Label']]
# Out:
#                   Coaster_P31Label Height_P2048               Park_P361Label  \
# 36             Top Thrill Dragster          128                  Cedar Point
# 49            Fiorano GT Challenge           21                           NA
# 51                        Tulireki         16.5                           NA
# 65                         Dodonpa           49              Fuji-Q Highland
# 80                Millennium Force           94                  Cedar Point
# 85                    Cheetah Hunt         31.1                           NA
# 106                           Ukko           52                           NA
# 143                      Verbolten          268   Busch Gardens Williamsburg
# 148                          Cobra         35.5               Walibi Belgium
# 175                  Full Throttle           49     Six Flags Magic Mountain
# 216                  Texas Tornado         24.4                           NA
# 262                         Salama           17                           NA
# 308            The Incredible Hulk          335     Marvel Super Hero Island
# 318                         Shaman           30                           NA
# 345                 Wicked Twister          655                  Cedar Point
# 348  Star Wars Hyperspace Mountain           32              Disneyland Park
# 351                         iSpeed           55                           NA
# 364                           Rita           21                           NA
# 367          Blue Fire Megacoaster           38                  Europa-Park
# 384                      Takabisha           43              Fuji-Q Highland
# 394                  Formula Rossa           52                           NA
# 425                        Tornado         22.9               Walibi Belgium
# 442                       Maverick           32                  Cedar Point
# 457                     Coccinelle          3.3               Walibi Belgium
# 469              Psyké Underground           42               Walibi Belgium
# 479             Tower of Terror II          115                           NA
# 485                         Mammut           14                           NA
# 535                 Kikkerachtbaan            8                           NA
# 536                          Taron           30                      Mystery
# 562                         Pulsar           45               Walibi Belgium
# 602              Curse of Novgorod           40                           NA
# 608                      Kingda Ka          139                           NA
# 619                         Mystic           31           Walibi Rhône-Alpes
# 620                      Tiki-Waka           21               Walibi Belgium
# 623                      Red Force          112           PortAventura World
# 629               TMNT Shellraiser          143         Nickelodeon Universe
# 634                           Hype           46                           NA
# 643     Harley Quinn Crazy Coaster         18.9  Six Flags Discovery Kingdom
# 646                         Mystic           31           Walibi Rhône-Alpes
# 655                    Dawson Duel           25                  Bellewaerde
# 658                  VelociCoaster          155                           NA
# 661          The Ride to Happiness           33                           NA
# 675       Eurosat - CanCan Coaster         25.5                  Europa-Park
#
#                  Location_P131Label          Country_P17Label
# 36                             Ohio  United States of America
# 49                               NA                        NA
# 51                       Alppiharju                   Finland
# 65                               NA                     Japan
# 80                             Ohio  United States of America
# 85                          Florida  United States of America
# 106                      Alppiharju                   Finland
# 143                        Virginia  United States of America
# 148                           Wavre                   Belgium
# 175                              NA  United States of America
# 216                           Texas  United States of America
# 262                      Alppiharju                   Finland
# 308                         Florida  United States of America
# 318           Castelnuovo del Garda                     Italy
# 345                            Ohio  United States of America
# 348                              NA                    France
# 351                              NA                     Italy
# 364                              NA            United Kingdom
# 367                            Rust                   Germany
# 384                              NA                     Japan
# 394                              NA      United Arab Emirates
# 425                           Wavre                   Belgium
# 442                            Ohio  United States of America
# 457                           Wavre                   Belgium
# 469                           Wavre                   Belgium
# 479                      Queensland                 Australia
# 485           Castelnuovo del Garda                     Italy
# 535                       Wassenaar               Netherlands
# 536                              NA                   Germany
# 562                              NA                   Belgium
# 602                      Sierksdorf                   Germany
# 608                      New Jersey  United States of America
# 619  Les Avenières-Veyrins-Thuellin                    France
# 620                              NA                   Belgium
# 623                           Salou                     Spain
# 629                              NA  United States of America
# 634                         Tampere                   Finland
# 643                         Vallejo  United States of America
# 646                   Les Avenières                    France
# 655                              NA                   Belgium
# 658                              NA  United States of America
# 661                        De Panne                   Belgium
# 675                            Rust                   Germany

# %%
r2.df['Height_P2048'] = r2.df[r2.df['Height_P2048'] != 'NA']['Height_P2048'].astype(float)
valid_height = r2.df[r2.df['Height_P2048'] > 0]
max_height_us = valid_height[valid_height['Country_P17Label'] == 'United States of America'].groupby('Location_P131Label').Height_P2048.agg(['count','max'])
max_height_world = valid_height.groupby('Country_P17Label').Height_P2048.agg(['count','max'])

print("Highest Roller Coaster per State (meters)")
print(max_height_us.sort_values(by=['max']))
print("\n","-"*50)
print("Highest Roller Coaster per Country (meters)")
print(max_height_world.sort_values(by=['max']))
# Out:
# Highest Roller Coaster per State (meters)
#                     count    max
# Location_P131Label
# Vallejo                 1   18.9
# Texas                   1   24.4
# New Jersey              1  139.0
# NA                      3  155.0
# Virginia                1  268.0
# Florida                 2  335.0
# Ohio                    4  655.0
#
#  --------------------------------------------------
# Highest Roller Coaster per Country (meters)
#                           count    max
# Country_P17Label
# Netherlands                   1    8.0
# NA                            1   21.0
# United Kingdom                1   21.0
# France                        3   32.0
# Germany                       4   40.0
# Belgium                       8   45.0
# Japan                         2   49.0
# Finland                       4   52.0
# United Arab Emirates          1   52.0
# Italy                         3   55.0
# Spain                         1  112.0
# Australia                     1  115.0
# United States of America     13  655.0

# %%
presidents = createRelation('Q11696') # Q11696 - 'President of the United States' in wikidata
presidents.extend('P39',True, 'President', limit=20, label=True) # P39 - 'position held'
presidents.changeFocus('President_P39')
presidents.extend('P26', False, 'Spouse', label=True) # P26 - 'spouse'
presidents.extend('P569', False, 'date_of_birth', label=True) # P569 - 'date of birth'
presidents.extend('P19',False, 'Place_of_birth', label=True) #P19 - 'place of birth'
presidents.query()
presidents.df[['President_P39Label','Spouse_P26Label','date_of_birth_P569Label','Place_of_birth_P19Label']]
# Out:
#               President_P39Label            Spouse_P26Label  \
# 0            Rutherford B. Hayes            Lucy Webb Hayes
# 1               Grover Cleveland          Frances Cleveland
# 2                Calvin Coolidge             Grace Coolidge
# 3   Gonzo the Mechanical Bastard                         NA
# 4              Caroline Reynolds                         NA
# 5                           Prez                         NA
# 6                    Gerald Ford                 Betty Ford
# 7                          Sylar                         NA
# 8            Rutherford B. Hayes            Lucy Webb Hayes
# 9                 Woodrow Wilson  Edith Bolling Galt Wilson
# 10              Millard Fillmore           Abigail Fillmore
# 11                Andrew Jackson             Rachel Jackson
# 12              William McKinley        Ida Saxton McKinley
# 13                  Wayne Palmer                         NA
# 14                 Roger Durling                         NA
# 15                     Joe Biden                 Jill Biden
# 16                  James Monroe           Elizabeth Monroe
# 17                     Doom 2099                         NA
# 18                Olivia Marsdin                         NA
# 19              Jake Featherston                         NA
#
#    date_of_birth_P569Label Place_of_birth_P19Label
# 0     1822-10-04T00:00:00Z                 Fremont
# 1     1837-03-18T00:00:00Z                Caldwell
# 2     1872-07-04T00:00:00Z          Plymouth Notch
# 3                       NA                      NA
# 4                       NA                      NA
# 5                       NA                      NA
# 6     1913-07-14T00:00:00Z                   Omaha
# 7                       NA                      NA
# 8     1822-10-04T00:00:00Z                Delaware
# 9     1856-12-28T00:00:00Z                Staunton
# 10    1800-01-07T00:00:00Z              Summerhill
# 11    1767-03-15T00:00:00Z                 Waxhaws
# 12    1843-01-29T00:00:00Z                   Niles
# 13                      NA                      NA
# 14                      NA                      NA
# 15    1942-11-20T00:00:00Z     St. Mary's Hospital
# 16    1758-04-28T00:00:00Z             Monroe Hall
# 17                      NA                      NA
# 18                      NA                      NA
# 19                      NA                      NA

# %%
r3 = createRelation('Q458') # Q458 - 'European Union' in wikidata
r3.extend('P150',False,'Country',label=True) # P150 - 'contains administrative territorial entity'
r3.extend('P1082',False, 'Total_population') # P1082 - 'Population'
r3.changeFocus('Country_P150')
r3.extend('P1082',False, 'Population')
r3.query()
r3.df[['Country_P150Label','Population_P1082']]
# Out:
#    Country_P150Label Population_P1082
# 0           Bulgaria          7000039
# 1            Finland          5501043
# 2           Slovenia          2066880
# 3            Croatia          4105493
# 4             Cyprus          1141166
# 5            Estonia          1324820
# 6        Netherlands         17282163
# 7             France         66628000
# 8         Luxembourg           626108
# 9           Slovakia          5397036
# 10            Poland         38382576
# 11           Austria          8809212
# 12          Portugal         10600000
# 13             Malta           465292
# 14           Germany         83149300
# 15    Czech Republic         10693939
# 16             Italy         60317000
# 17            Sweden         10373225
# 18           Ireland          4761865
# 19           Belgium         11431406
# 20            Latvia          1909000
# 21           Denmark          5827463
# 22           Hungary          9769526
# 23         Lithuania          2790842
# 24            Greece         10760421
# 25           Romania         19586539
# 26             Spain         46733038

# %%
import matplotlib.pyplot as plt
r3.df['Population_P1082'] = r3.df['Population_P1082'].astype(int)
pop_data = r3.df.sort_values(by=['Population_P1082'])
labels = pop_data['Country_P150Label']
sizes = pop_data['Population_P1082']

fig1, ax1 = plt.subplots(figsize=[10,10])
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', rotatelabels=True,
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
def adjustedGDP(gdp: WikiDataProperty(['P2131', 'P2132']), timestamp: WikiDataProperty(['P585'])):
      inflationIndex = pd.read_csv('test_data/inflation_index.csv')
      base = inflationIndex.iloc[-1]['Index']
      timestamp = timestamp[:10]
      inflationIndex.set_index('Date',inplace=True)
      if timestamp in inflationIndex.index:
          return math.floor(float(gdp) / inflationIndex.loc[timestamp]['Index'] * base)
      return math.floor(float(gdp))

usgdp = createRelation('Q30') # Q30 - 'United States of America'
usgdp.extend('P2131', False, 'GDP', colVerbose=True,rowVerbose=True) # P2131 - 'nominal GDP'
usgdp.query()
usgdp.extendWithFunction(['GDP_P2131','GDP_point_in_time_P2131_P585'], adjustedGDP, 'adjustedGDP_P2131') # base 2014
usgdp.df
# Out:
#                              Entity ID       GDP_P2131  \
# 0   http://www.wikidata.org/entity/Q30  16155255000000
# 1   http://www.wikidata.org/entity/Q30   1167770000000
# 2   http://www.wikidata.org/entity/Q30  16691517000000
# 3   http://www.wikidata.org/entity/Q30   4590155000000
# 4   http://www.wikidata.org/entity/Q30   8100201000000
# 5   http://www.wikidata.org/entity/Q30  17427609000000
# 6   http://www.wikidata.org/entity/Q30   1282449000000
# 7   http://www.wikidata.org/entity/Q30  19390604000000
# 8   http://www.wikidata.org/entity/Q30   2356571000000
# 9   http://www.wikidata.org/entity/Q30  14964372000000
# 10  http://www.wikidata.org/entity/Q30   2085951000000
# 11  http://www.wikidata.org/entity/Q30    815000000000
# 12  http://www.wikidata.org/entity/Q30   7664060000000
# 13  http://www.wikidata.org/entity/Q30    685800000000
# 14  http://www.wikidata.org/entity/Q30   6539299000000
# 15  http://www.wikidata.org/entity/Q30  12274928000000
# 16  http://www.wikidata.org/entity/Q30   5252629000000
# 17  http://www.wikidata.org/entity/Q30   1428549000000
# 18  http://www.wikidata.org/entity/Q30  10977514000000
# 19  http://www.wikidata.org/entity/Q30    743700000000
# 20  http://www.wikidata.org/entity/Q30   8608515000000
# 21  http://www.wikidata.org/entity/Q30   3344991000000
# 22  http://www.wikidata.org/entity/Q30    942500000000
# 23  http://www.wikidata.org/entity/Q30    861700000000
# 24  http://www.wikidata.org/entity/Q30  13855888000000
# 25  http://www.wikidata.org/entity/Q30   4870217000000
# 26  http://www.wikidata.org/entity/Q30   6878718000000
# 27  http://www.wikidata.org/entity/Q30   1075884000000
# 28  http://www.wikidata.org/entity/Q30   9089168000000
# 29  http://www.wikidata.org/entity/Q30    543300000000
# 30  http://www.wikidata.org/entity/Q30   1877587000000
# 31  http://www.wikidata.org/entity/Q30  14418739000000
# 32  http://www.wikidata.org/entity/Q30    605100000000
# 33  http://www.wikidata.org/entity/Q30   2632143000000
# 34  http://www.wikidata.org/entity/Q30   9660624000000
# 35  http://www.wikidata.org/entity/Q30   1688923000000
# 36  http://www.wikidata.org/entity/Q30    638600000000
# 37  http://www.wikidata.org/entity/Q30  14477635000000
# 38  http://www.wikidata.org/entity/Q30   5979589000000
# 39  http://www.wikidata.org/entity/Q30   7308755000000
# 40  http://www.wikidata.org/entity/Q30   1019900000000
# 41  http://www.wikidata.org/entity/Q30   2862505000000
# 42  http://www.wikidata.org/entity/Q30  10621824000000
# 43  http://www.wikidata.org/entity/Q30  13093726000000
# 44  http://www.wikidata.org/entity/Q30  18624475000000
# 45  http://www.wikidata.org/entity/Q30  11510670000000
# 46  http://www.wikidata.org/entity/Q30   1548825000000
# 47  http://www.wikidata.org/entity/Q30   3210956000000
# 48  http://www.wikidata.org/entity/Q30    563300000000
# 49  http://www.wikidata.org/entity/Q30  10284779000000
# 50  http://www.wikidata.org/entity/Q30   5657693000000
# 51  http://www.wikidata.org/entity/Q30   4040693000000
# 52  http://www.wikidata.org/entity/Q30  14718582000000
# 53  http://www.wikidata.org/entity/Q30   4346734000000
# 54  http://www.wikidata.org/entity/Q30  18120714000000
# 55  http://www.wikidata.org/entity/Q30   3638137000000
# 56  http://www.wikidata.org/entity/Q30   6174043000000
# 57  http://www.wikidata.org/entity/Q30  15517926000000
#
#                         GDP_rank_P2131_rank GDP_point_in_time_P2131_P585  \
# 0      http://wikiba.se/ontology#NormalRank         2012-01-01T00:00:00Z
# 1      http://wikiba.se/ontology#NormalRank         1971-01-01T00:00:00Z
# 2      http://wikiba.se/ontology#NormalRank         2013-01-01T00:00:00Z
# 3      http://wikiba.se/ontology#NormalRank         1986-01-01T00:00:00Z
# 4      http://wikiba.se/ontology#NormalRank         1996-01-01T00:00:00Z
# 5      http://wikiba.se/ontology#NormalRank         2014-01-01T00:00:00Z
# 6      http://wikiba.se/ontology#NormalRank         1972-01-01T00:00:00Z
# 7   http://wikiba.se/ontology#PreferredRank         2017-01-01T00:00:00Z
# 8      http://wikiba.se/ontology#NormalRank         1978-01-01T00:00:00Z
# 9      http://wikiba.se/ontology#NormalRank         2010-01-01T00:00:00Z
# 10     http://wikiba.se/ontology#NormalRank         1977-01-01T00:00:00Z
# 11     http://wikiba.se/ontology#NormalRank         1966-01-01T00:00:00Z
# 12     http://wikiba.se/ontology#NormalRank         1995-01-01T00:00:00Z
# 13     http://wikiba.se/ontology#NormalRank         1964-01-01T00:00:00Z
# 14     http://wikiba.se/ontology#NormalRank         1992-01-01T00:00:00Z
# 15     http://wikiba.se/ontology#NormalRank         2004-01-01T00:00:00Z
# 16     http://wikiba.se/ontology#NormalRank         1988-01-01T00:00:00Z
# 17     http://wikiba.se/ontology#NormalRank         1973-01-01T00:00:00Z
# 18     http://wikiba.se/ontology#NormalRank         2002-01-01T00:00:00Z
# 19     http://wikiba.se/ontology#NormalRank         1965-01-01T00:00:00Z
# 20     http://wikiba.se/ontology#NormalRank         1997-01-01T00:00:00Z
# 21     http://wikiba.se/ontology#NormalRank         1982-01-01T00:00:00Z
# 22     http://wikiba.se/ontology#NormalRank         1968-01-01T00:00:00Z
# 23     http://wikiba.se/ontology#NormalRank         1967-01-01T00:00:00Z
# 24     http://wikiba.se/ontology#NormalRank         2006-01-01T00:00:00Z
# 25     http://wikiba.se/ontology#NormalRank         1987-01-01T00:00:00Z
# 26     http://wikiba.se/ontology#NormalRank         1993-01-01T00:00:00Z
# 27     http://wikiba.se/ontology#NormalRank         1970-01-01T00:00:00Z
# 28     http://wikiba.se/ontology#NormalRank         1998-01-01T00:00:00Z
# 29     http://wikiba.se/ontology#NormalRank         1960-01-01T00:00:00Z
# 30     http://wikiba.se/ontology#NormalRank         1976-01-01T00:00:00Z
# 31     http://wikiba.se/ontology#NormalRank         2009-01-01T00:00:00Z
# 32     http://wikiba.se/ontology#NormalRank         1962-01-01T00:00:00Z
# 33     http://wikiba.se/ontology#NormalRank         1979-01-01T00:00:00Z
# 34     http://wikiba.se/ontology#NormalRank         1999-01-01T00:00:00Z
# 35     http://wikiba.se/ontology#NormalRank         1975-01-01T00:00:00Z
# 36     http://wikiba.se/ontology#NormalRank         1963-01-01T00:00:00Z
# 37     http://wikiba.se/ontology#NormalRank         2007-01-01T00:00:00Z
# 38     http://wikiba.se/ontology#NormalRank         1990-01-01T00:00:00Z
# 39     http://wikiba.se/ontology#NormalRank         1994-01-01T00:00:00Z
# 40     http://wikiba.se/ontology#NormalRank         1969-01-01T00:00:00Z
# 41     http://wikiba.se/ontology#NormalRank         1980-01-01T00:00:00Z
# 42     http://wikiba.se/ontology#NormalRank         2001-01-01T00:00:00Z
# 43     http://wikiba.se/ontology#NormalRank         2005-01-01T00:00:00Z
# 44     http://wikiba.se/ontology#NormalRank         2016-01-01T00:00:00Z
# 45     http://wikiba.se/ontology#NormalRank         2003-01-01T00:00:00Z
# 46     http://wikiba.se/ontology#NormalRank         1974-01-01T00:00:00Z
# 47     http://wikiba.se/ontology#NormalRank         1981-01-01T00:00:00Z
# 48     http://wikiba.se/ontology#NormalRank         1961-01-01T00:00:00Z
# 49     http://wikiba.se/ontology#NormalRank         2000-01-01T00:00:00Z
# 50     http://wikiba.se/ontology#NormalRank         1989-01-01T00:00:00Z
# 51     http://wikiba.se/ontology#NormalRank         1984-01-01T00:00:00Z
# 52     http://wikiba.se/ontology#NormalRank         2008-01-01T00:00:00Z
# 53     http://wikiba.se/ontology#NormalRank         1985-01-01T00:00:00Z
# 54     http://wikiba.se/ontology#NormalRank         2015-01-01T00:00:00Z
# 55     http://wikiba.se/ontology#NormalRank         1983-01-01T00:00:00Z
# 56     http://wikiba.se/ontology#NormalRank         1991-01-01T00:00:00Z
# 57     http://wikiba.se/ontology#NormalRank         2011-01-01T00:00:00Z
#
#       GDP_ref_P2131_P813                        GDP_ref_P2131_P248  \
# 0   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 1   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 2   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 3   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 4   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 5   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 6   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 7   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 8   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 9   2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 10  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 11  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 12  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 13  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 14  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 15  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 16  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 17  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 18  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 19  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 20  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 21  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 22  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 23  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 24  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 25  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 26  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 27  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 28  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 29  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 30  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 31  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 32  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 33  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 34  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 35  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 36  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 37  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 38  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 39  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 40  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 41  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 42  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 43  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 44  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 45  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 46  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 47  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 48  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 49  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 50  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 51  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 52  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 53  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 54  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 55  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 56  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
# 57  2018-10-18T00:00:00Z  http://www.wikidata.org/entity/Q21540096
#
#                           GDP_ref_P2131_P275  \
# 0   http://www.wikidata.org/entity/Q20007257
# 1   http://www.wikidata.org/entity/Q20007257
# 2   http://www.wikidata.org/entity/Q20007257
# 3   http://www.wikidata.org/entity/Q20007257
# 4   http://www.wikidata.org/entity/Q20007257
# 5   http://www.wikidata.org/entity/Q20007257
# 6   http://www.wikidata.org/entity/Q20007257
# 7   http://www.wikidata.org/entity/Q20007257
# 8   http://www.wikidata.org/entity/Q20007257
# 9   http://www.wikidata.org/entity/Q20007257
# 10  http://www.wikidata.org/entity/Q20007257
# 11  http://www.wikidata.org/entity/Q20007257
# 12  http://www.wikidata.org/entity/Q20007257
# 13  http://www.wikidata.org/entity/Q20007257
# 14  http://www.wikidata.org/entity/Q20007257
# 15  http://www.wikidata.org/entity/Q20007257
# 16  http://www.wikidata.org/entity/Q20007257
# 17  http://www.wikidata.org/entity/Q20007257
# 18  http://www.wikidata.org/entity/Q20007257
# 19  http://www.wikidata.org/entity/Q20007257
# 20  http://www.wikidata.org/entity/Q20007257
# 21  http://www.wikidata.org/entity/Q20007257
# 22  http://www.wikidata.org/entity/Q20007257
# 23  http://www.wikidata.org/entity/Q20007257
# 24  http://www.wikidata.org/entity/Q20007257
# 25  http://www.wikidata.org/entity/Q20007257
# 26  http://www.wikidata.org/entity/Q20007257
# 27  http://www.wikidata.org/entity/Q20007257
# 28  http://www.wikidata.org/entity/Q20007257
# 29  http://www.wikidata.org/entity/Q20007257
# 30  http://www.wikidata.org/entity/Q20007257
# 31  http://www.wikidata.org/entity/Q20007257
# 32  http://www.wikidata.org/entity/Q20007257
# 33  http://www.wikidata.org/entity/Q20007257
# 34  http://www.wikidata.org/entity/Q20007257
# 35  http://www.wikidata.org/entity/Q20007257
# 36  http://www.wikidata.org/entity/Q20007257
# 37  http://www.wikidata.org/entity/Q20007257
# 38  http://www.wikidata.org/entity/Q20007257
# 39  http://www.wikidata.org/entity/Q20007257
# 40  http://www.wikidata.org/entity/Q20007257
# 41  http://www.wikidata.org/entity/Q20007257
# 42  http://www.wikidata.org/entity/Q20007257
# 43  http://www.wikidata.org/entity/Q20007257
# 44  http://www.wikidata.org/entity/Q20007257
# 45  http://www.wikidata.org/entity/Q20007257
# 46  http://www.wikidata.org/entity/Q20007257
# 47  http://www.wikidata.org/entity/Q20007257
# 48  http://www.wikidata.org/entity/Q20007257
# 49  http://www.wikidata.org/entity/Q20007257
# 50  http://www.wikidata.org/entity/Q20007257
# 51  http://www.wikidata.org/entity/Q20007257
# 52  http://www.wikidata.org/entity/Q20007257
# 53  http://www.wikidata.org/entity/Q20007257
# 54  http://www.wikidata.org/entity/Q20007257
# 55  http://www.wikidata.org/entity/Q20007257
# 56  http://www.wikidata.org/entity/Q20007257
# 57  http://www.wikidata.org/entity/Q20007257
#
#                                    GDP_ref_P2131_P854 Basic ID  \
# 0   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 1   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 2   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 3   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 4   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 5   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 6   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 7   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 8   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 9   https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 10  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 11  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 12  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 13  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 14  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 15  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 16  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 17  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 18  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 19  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 20  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 21  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 22  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 23  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 24  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 25  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 26  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 27  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 28  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 29  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 30  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 31  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 32  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 33  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 34  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 35  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 36  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 37  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 38  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 39  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 40  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 41  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 42  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 43  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 44  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 45  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 46  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 47  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 48  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 49  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 50  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 51  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 52  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 53  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 54  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 55  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 56  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
# 57  https://data.worldbank.org/indicator/NY.GDP.MK...      Q30
#
#     adjustedGDP_P2131
# 0      16672060655946
# 1       6863318776884
# 2      16955067268421
# 3       9796630446897
# 4      12271804515000
# 5      17427609000000
# 6       7298913388905
# 7      19390604000000
# 8       8819834592576
# 9      16154204178155
# 10      8340808788307
# 11      5995016981132
# 12     11927786154091
# 13      5191572582524
# 14     11076369767443
# 15     15503790810194
# 16     10619481116369
# 17      7844142438591
# 18     14499244296013
# 19      5575747730769
# 20     12656627245380
# 21      8297422213743
# 22      6465273607038
# 23      6126608425531
# 24     16344497717639
# 25     10244799278525
# 26     11283605888415
# 27      6657843432380
# 28     13156570680000
# 29      4337425351535
# 30      7899238141942
# 31     15973883822452
# 32      4718085720000
# 33      9014646588404
# 34     13753953278052
# 35      7582842849673
# 36      4913774921052
# 37     16730646137953
# 38     10978975985274
# 39     11693808034062
# 40      6701430573033
# 41      8606500251670
# 42     14189689222067
# 43     16060996387079
# 44     18624475000000
# 45     14818546415630
# 46      7774569714592
# 47      8633264180413
# 48      4421640362416
# 49     14252217799549
# 50     10928364292221
# 51      9275591204985
# 52     16310933423877
# 53      9637636306578
# 54     18120714000000
# 55      8701620189079
# 56     10729624386240
# 57     16482797792310

# %%
gdp_data = usgdp.df.sort_values(by=['GDP_point_in_time_P2131_P585'])

xvals = list(map(lambda x: int(x[:4]), gdp_data['GDP_point_in_time_P2131_P585']))
yvals = list(map(lambda x: float(x)/1000000000000, gdp_data['adjustedGDP_P2131']))

plt.figure(figsize=[14,8])
plt.plot(xvals, yvals)
plt.title("US GDP, Adjusted for Inflation")
plt.ylabel("Adjusted GDP (Trillons of Dollars)")
# Out:
# Text(0, 0.5, 'Adjusted GDP (Trillons of Dollars)')

# %% [markdown]
# # National Parks

# %%
entity_subclass = 'national_park'
qnum = 'Q34918903' # "National Park of the United States"
r = createRelation(qnum, label=True)
r.extend('P31', True, 'entity_subclass', label=True) # extend via property P31 = is instance of

r.changeFocus('entity_subclass_P31')
r.extend('P17', False, 'Country',label=True, search="Q30") # extend via property P17 = is in country
# r.extend('P131', False, 'State', label=True)
r.extend('P625', False, 'Lon_Lat')
r.extend('P571', False, 'Inception')
r.query()

print('There are %s instances of %s in the US.' % (str(len(r.df)), entity_subclass))
# Out:
# There are 77 instances of national_park in the US.

# %%
r.df
# Out:
#                                    Entity ID  \
# 0   http://www.wikidata.org/entity/Q34918903
# 1   http://www.wikidata.org/entity/Q34918903
# 2   http://www.wikidata.org/entity/Q34918903
# 3   http://www.wikidata.org/entity/Q34918903
# 4   http://www.wikidata.org/entity/Q34918903
# ..                                       ...
# 72  http://www.wikidata.org/entity/Q34918903
# 73  http://www.wikidata.org/entity/Q34918903
# 74  http://www.wikidata.org/entity/Q34918903
# 75  http://www.wikidata.org/entity/Q34918903
# 76  http://www.wikidata.org/entity/Q34918903
#
#                         entity_subclass_P31  \
# 0    http://www.wikidata.org/entity/Q836264
# 1    http://www.wikidata.org/entity/Q205952
# 2    http://www.wikidata.org/entity/Q841503
# 3    http://www.wikidata.org/entity/Q866080
# 4    http://www.wikidata.org/entity/Q305880
# ..                                      ...
# 72   http://www.wikidata.org/entity/Q217136
# 73   http://www.wikidata.org/entity/Q239304
# 74   http://www.wikidata.org/entity/Q129902
# 75  http://www.wikidata.org/entity/Q7011245
# 76  http://www.wikidata.org/entity/Q1783768
#
#                       entity_subclass_P31Label  \
# 0                   Kobuk Valley National Park
# 1              Hawaiʻi Volcanoes National Park
# 2                   Kenai Fjords National Park
# 3                       Biscayne National Park
# 4   Black Canyon of the Gunnison National Park
# ..                                         ...
# 72           Denali National Park and Preserve
# 73                   Crater Lake National Park
# 74                  Capitol Reef National Park
# 75  New River Gorge National Park and Preserve
# 76                     Pinnacles National Park
#
#                            Country_P17          Country_P17Label  \
# 0   http://www.wikidata.org/entity/Q30  United States of America
# 1   http://www.wikidata.org/entity/Q30  United States of America
# 2   http://www.wikidata.org/entity/Q30  United States of America
# 3   http://www.wikidata.org/entity/Q30  United States of America
# 4   http://www.wikidata.org/entity/Q30  United States of America
# ..                                 ...                       ...
# 72  http://www.wikidata.org/entity/Q30  United States of America
# 73  http://www.wikidata.org/entity/Q30  United States of America
# 74  http://www.wikidata.org/entity/Q30  United States of America
# 75  http://www.wikidata.org/entity/Q30  United States of America
# 76  http://www.wikidata.org/entity/Q30  United States of America
#
#                           Lon_Lat_P625        Inception_P571   Basic ID
# 0          Point(-159.283333333 67.55)  1980-12-02T00:00:00Z  Q34918903
# 1           Point(-155.12361 19.40083)  1916-01-01T00:00:00Z  Q34918903
# 2           Point(-150.10857 59.81571)  1980-01-01T00:00:00Z  Q34918903
# 3      Point(-80.18096924 25.50185493)  1980-06-28T00:00:00Z  Q34918903
# 4   Point(-107.716666666 38.566666666)  1933-03-02T00:00:00Z  Q34918903
# ..                                 ...                   ...        ...
# 72                  Point(-150.3 63.2)  1917-01-01T00:00:00Z  Q34918903
# 73  Point(-122.148055555 42.911944444)  1902-01-01T00:00:00Z  Q34918903
# 74                Point(-111.167 38.2)  1937-08-02T00:00:00Z  Q34918903
# 75             Point(-81.0817 37.9608)  2020-12-27T00:00:00Z  Q34918903
# 76             Point(-121.167 36.4869)  2013-01-10T00:00:00Z  Q34918903
#
# [77 rows x 8 columns]

# %% [markdown]
# #### Visit 20 national parks in order.

# %%
func_lib.arrow_map(r.df[20:40], 'Inception_P571', 'Lon_Lat_P625', 'entity_subclass_P31Label', 'Visiting National Parks in the US')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d92a04cf8204> in <module>
# ----> 1 func_lib.arrow_map(r.df[20:40], 'Inception_P571', 'Lon_Lat_P625', 'entity_subclass_P31Label', 'Visiting National Parks in the US')
#
# ~/knp/KNP/client/knps/func_lib.py in arrow_map(df, date_col_name, coord_col_name, entity_name, plot_title)
#     263                   alpha=((1-base_alpha)/(len(df)))*ind+base_alpha)
#     264         rad = (1/len(date_coords_list_sorted))*ind
# --> 265         a = patches.FancyArrowPatch((x, y), (x_next, y_next),
#     266                                      connectionstyle="arc3,rad=%s" % str(rad), **kw)
#     267         plt.gca().add_patch(a)
#
# NameError: name 'patches' is not defined
